# %%
# %pip install google-generativeai python-dotenv pillow requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import requests

# --- API 키 설정 (환경에 맞게 선택) ---
# VS Code / Codespaces 용
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

# 이미지 URL
image_url = "https://images.unsplash.com/photo-1736264335247-8ec5664c8328?q=80&w=1887&auto=format&fit=crop&ixlib-rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"

try:
    # URL에서 이미지 데이터 다운로드
    response = requests.get(image_url)
    response.raise_for_status()  # 요청 성공 여부 확인

    # 텍스트 프롬프트와 이미지 데이터를 딕셔너리 형태로 준비
    image_data = {
        'mime_type': 'image/jpeg', # 이미지 형식 지정
        'data': response.content   # 이미지의 원본 바이트 데이터
    }

    # Gemini-Pro-Vision 모델 선택
    model = genai.GenerativeModel('gemini-2.5-pro')

    # 프롬프트와 이미지 데이터 전달
    prompt = "이 이미지에 대해 설명해주세요."
    response = model.generate_content([prompt, image_data])

    # 결과 출력
    print(response.text)

except requests.exceptions.RequestException as e:
    print(f"이미지를 불러오는 데 실패했습니다: {e}")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 이 사진은 현대적인 주방에서 한 여성이 즐겁게 아침 식사를 준비하는 모습을 담고 있습니다.
#
# 전체적으로 어둡고 대비가 강한 조명 아래, 인물에 초점이 맞춰져 있어 매우 스타일리시하고 생동감 있는 분위기를 자아냅니다.
#
# **사진에 대한 자세한 설명:**
#
# *   **인물:** 금발 머리를 포니테일로 묶은 젊은 여성이 환하게 웃고 있습니다. 그녀는 검은색 스포츠 브라와 레깅스 차림으로 건강하고 활기찬 모습입니다.
# *   **행동:** 여성은 밝은 파란색 그릇에 담긴 계란을 거품기로 젓고 있습니다. 바로 옆 프라이팬에서는 베이컨 두 조각이 지글지글 익어가고 있습니다.
# *   **배경 및 환경:** 주방은 세련된 검은색 톤으로 꾸며져 있습니다. 배경의 창문 너머로 밝은 바깥 풍경이 보입니다. 카운터에는 샴페인 '뵈브 클리코(Veuve Clicquot)' 상자가 놓여 있어 일상 속 특별한 순간임을 암시하기도 합니다.
# *   **사진의 특징:** 사진은 의도적으로 거친 입자(그레인) 효과를 주어 필름 사진 같은 감성을 더했으며, 인물에 집중된 조명으로 극적인 효과를 연출하고 있습니다.
#
# 요약하자면, 평범한 요리의 순간을 감각적이고 활기차게 포착한 라이프스타일 사진이라고 할 수 있습니다.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import requests

# --- API 키 설정 (환경에 맞게 선택) ---
# VS Code / Codespaces 용
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

# 이미지 URL
image_url = "https://img.hankyung.com/photo/202312/01.35399315.1.jpg"

try:
    # URL에서 이미지 데이터 다운로드
    response = requests.get(image_url)
    response.raise_for_status()  # 요청 성공 여부 확인

    # 텍스트 프롬프트와 이미지 데이터를 딕셔너리 형태로 준비
    image_data = {
        'mime_type': 'image/jpeg', # 이미지 형식 지정
        'data': response.content   # 이미지의 원본 바이트 데이터
    }

    # Gemini-Pro-Vision 모델 선택
    model = genai.GenerativeModel('gemini-2.5-pro')

    # 프롬프트와 이미지 데이터 전달
    prompt = "이 이미지에 대해 설명해주세요."
    response = model.generate_content([prompt, image_data])

    # 결과 출력
    print(response.text)

except requests.exceptions.RequestException as e:
    print(f"이미지를 불러오는 데 실패했습니다: {e}")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 네, 이 이미지는 프랑스 후기 인상주의 화가 **조르주 쇠라(Georges Seurat)**의 1884년 작품인 **<아스니에르에서의 물놀이>(Bathers at Asnières)**입니다.
#
# 이 그림에 대한 자세한 설명은 다음과 같습니다.
#
# ### 작품의 개요
# *   **작가:** 조르주 쇠라 (Georges Seurat)
# *   **제작 연도:** 1884년
# *   **사조:** 후기 인상주의 (Post-Impressionism), 점묘법 (Pointillism)의 초기 형태
# *   **소장처:** 런던 내셔널 갤러리 (National Gallery, London)
#
# ### 상세 설명
#
# 1.  **장면 묘사:**
#     *   그림은 파리 근교의 센 강변에서 더운 여름날 오후를 즐기는 사람들의 모습을 담고 있습니다.
#     *   전경에는 풀밭에 편안하게 누워있거나 앉아있는 남성들이 있습니다. 중산모를 쓴 남성은 강아지와 함께 누워 쉬고 있고, 밀짚모자를 쓴 다른 남성은 강을 바라보며 사색에 잠겨 있습니다.
#     *   중심부에는 붉은색 수영복을 입은 소년이 강가에 앉아 발을 담그고 있고, 물속에는 빨간 모자를 쓴 소년이 입에 두 손을 모아 소리를 지르는 듯한 포즈를 취하고 있습니다.
#     *   강에는 요트와 나룻배가 떠다니며 평화로운 분위기를 더합니다.
#     *   배경에는 강 건너편의 다리와 공장 굴뚝이 보이며, 굴뚝에서는 연기가 피어오르고 있습니다.
#
# 2.  **예술적 기법 및 특징:**
# ...

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import mimetypes # 파일 타입 확인을 위해 추가 컴퓨터는 파일 확장자(.jpg, .pdf)만 보고 파일 종류를 판단하지 않음.
#특히 웹 브라우저는 서버로부터 파일을 받을 때, 이 MIME 타입을 보고 어떻게 처리할지 결정

# --- API 키 설정 ---
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

try:
    # 1. 분석할 로컬 이미지 파일의 경로를 지정합니다.
    #    (스크립트와 같은 폴더에 이미지가 있다고 가정)
    image_path = r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133893700991232898.jpg"

    # 2. 파일 확장자를 기반으로 MIME 타입을 자동으로 알아냅니다.
    mime_type, _ = mimetypes.guess_type(image_path)
    if mime_type is None:
        raise ValueError(f"'{image_path}' 파일의 MIME 타입을 확인할 수 없습니다.")

    # 3. 파일을 바이너리 읽기 모드('rb')로 열어 데이터를 읽습니다.
    with open(image_path, 'rb') as f:
        image_bytes = f.read()
    # -------------------

    # 텍스트 프롬프트와 이미지 데이터를 딕셔너리 형태로 준비
    image_data = {
        'mime_type': mime_type,
        'data': image_bytes  # 파일에서 직접 읽은 바이트 데이터
    }

    model = genai.GenerativeModel('gemini-2.5-pro')

    # 프롬프트와 이미지 데이터 전달
    prompt = "이 이미지에 대해 설명해주세요."
    response = model.generate_content([prompt, image_data])

    # 결과 출력
    print(response.text)

except FileNotFoundError:
    print(f"오류: '{image_path}' 파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 네, 이 이미지에 대해 설명해 드리겠습니다.
#
# 이 사진은 해가 지고 있는 아프리카의 넓은 사바나 초원을 배경으로 세 마리의 기린이 서 있는 모습을 담고 있습니다.
#
# **주요 특징은 다음과 같습니다:**
#
# *   **주요 대상:** 이미지 중앙에는 세 마리의 기린이 함께 서 있습니다. 이들은 가족처럼 보이며, 모두 오른쪽을 향해 비슷한 방향을 바라보고 있습니다. 긴 목과 독특한 얼룩무늬가 선명하게 보입니다.
# *   **배경:** 배경에는 지는 해(일몰)가 만들어내는 강렬하고 따뜻한 주황색과 노란색의 하늘이 펼쳐져 있습니다. 태양은 멀리 보이는 산등성이 너머로 막 넘어가고 있습니다.
# *   **환경:** 기린들이 서 있는 곳은 마른 풀로 뒤덮인 광활한 초원입니다. 전체적인 풍경이 황금빛으로 물들어 있습니다.
# *   **분위기:** 강렬한 석양빛이 모든 것을 비추어 전체적으로 매우 평화롭고, 고요하며, 장엄한 분위기를 자아냅니다. 아프리카 대자연의 아름다움과 신비로움을 느낄 수 있는 인상적인 장면입니다.
#
# 요약하자면, **"아프리카의 황금빛 석양을 배경으로 평화롭게 서 있는 세 마리 기린의 아름다운 실루엣"**이라고 할 수 있습니다.

# %%
import base64

# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
    
image_path = r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133893700991232898.jpg"

# 이미지를 base64로 인코딩
base64_image = encode_image(image_path)

print(base64_image)
# Out:
# ...

# %%
#점검용 코드
import base64, os

def encode_image(image_path: str) -> str:
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"파일을 찾을 수 없습니다: {image_path}")
    size = os.path.getsize(image_path)
    if size == 0:
        raise ValueError("파일 크기가 0바이트입니다.")
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

image_path = r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133893700991232898.jpg"

try:
    b64 = encode_image(image_path)

    # 전체를 찍지 말고 길이와 앞/뒤 일부만 출력
    print(f"✅ 인코딩 완료: 길이={len(b64):,} chars")
    print("앞부분(100):", b64[:100])
    print("뒷부분(100):", b64[-100:])

    # 필요하면 data URL로 조합해서 변수에 저장만 하고 콘솔에는 길이만 표시
    data_url = f"data:image/jpeg;base64,{b64}"
    print(f"data URL 길이={len(data_url):,} chars  (콘솔에 전부 출력 안 함)")

except Exception as e:
    print("에러:", e)
# Out:
# ✅ 인코딩 완료: 길이=2,908,068 chars
# 앞부분(100): /9j/4QAYRXhpZgAASUkqAAgAAAAAAAAAAAAAAP/sABFEdWNreQABAAQAAABQAAD/7gAOQWRvYmUAZMAAAAAB/9sAhAACAgICAgIC
# 뒷부분(100): x+9iZr2RRIbTAdaSpt9BO1arajQHrVdu28uJLi+SeqFbGlLR1ZxeeznG8pHbx7qYzSrN3aWdyh2SQLUsXXayLLXYlDaVXof/2Q==
# data URL 길이=2,908,091 chars  (콘솔에 전부 출력 안 함)

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import base64  # base64 라이브러리를 import 합니다.

# 실제 코드에서는 이 base64_image 변수만 준비되면 됩니다.
def encode_image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# 예시 이미지 파일 경로
image_path =r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133893700991232898.jpg"
if not os.path.exists(image_path):
    raise FileNotFoundError(f"'{image_path}' 파일을 찾을 수 없습니다.")

# 이미지를 base64 문자열로 인코딩 (이 변수가 준비물입니다)
base64_image = encode_image_to_base64(image_path)
# ----------------------------------------------------------------

# --- API 키 설정 ---
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

try:
    # --- 수정된 부분 ---
    # 1. requests 라이브러리를 사용하지 않습니다.
    # 2. Base64 문자열을 직접 디코딩하여 이미지 바이트를 얻습니다.
    image_bytes = base64.b64decode(base64_image)
    
    # 텍스트 프롬프트와 이미지 데이터를 딕셔너리 형태로 준비
    image_data = {
        'mime_type': 'image/jpeg',  # 이미지 형식 지정
        'data': image_bytes         # 디코딩된 바이트 데이터
    }
    # -------------------

    # 모델 설정
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash", #최신 모델 사용 권장
        generation_config=genai.types.GenerationConfig(
            temperature=0.2,
            top_p=0.95,
            max_output_tokens=2048,
        )
    )

    # 프롬프트와 이미지 데이터 전달
    prompt = "이 이미지에 대해 설명해주세요."
    response = model.generate_content([prompt, image_data])

    # 결과 출력
    print(response.text)

except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 이 이미지는 아프리카 사바나의 아름다운 일몰 또는 일출 풍경을 담고 있습니다.
#
# **전반적인 분위기:**
# 사진 전체는 따뜻하고 황홀한 오렌지색과 황금빛으로 물들어 있어 평화롭고 웅장한 분위기를 자아냅니다.
#
# **하늘:**
# 하늘은 강렬한 주황색과 황금빛으로 물들어 있으며, 지평선 가까이에는 밝고 둥근 해가 빛나고 있습니다. 해는 멀리 있는 산맥의 실루엣 뒤로 부분적으로 가려져 있어 신비로운 느낌을 줍니다. 하늘의 색상은 위쪽은 좀 더 밝은 오렌지색에서 아래쪽으로 갈수록 짙은 주황색과 붉은색으로 그라데이션을 이룹니다.
#
# **풍경:**
# 넓게 펼쳐진 대지는 건조한 황금빛 풀들로 가득 차 있습니다. 키 큰 풀들이 바람에 흔들리는 듯한 질감을 보여주며, 아프리카 사바나의 전형적인 모습을 연출합니다. 멀리 지평선에는 희미한 보라색 또는 붉은색을 띠는 산맥이 길게 늘어서 있어 깊이감을 더합니다. 일부 작은 나무나 덤불들이 풀밭 곳곳에 흩어져 있습니다.
#
# **기린:**
# 이미지의 중앙에는 세 마리의 기린이 서 있습니다. 이들은 긴 목과 독특한 갈색 얼룩무늬를 선명하게 드러내며, 당당하고 평화로운 모습으로 서 있습니다. 가장 키가 큰 기린은 왼쪽에 있고, 그 옆으로 두 마리가 나란히 서 있는 모습입니다. 기린들의 실루엣은 노을빛을 받아 더욱 돋보이며, 그들의 존재감이 풍경에 생명력을 불어넣습니다.
#
# 전반적으로 이 사진은 아프리카 야생의 아름다움과 평온함을 동시에 전달하며, 보는 이에게 깊은 감동을 주는 풍경화 같은 이미지입니다.

# %%
# pip install google-generativeai python-dotenv

import os, base64
from dotenv import load_dotenv
import google.generativeai as genai

# ── 0) API 키 ────────────────────────────────────────────────────────────
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("API 키(GOOGLE_API_KEY)를 설정해주세요.")
genai.configure(api_key=api_key)

# ── 1) base64 문자열 준비 ────────────────────────────────────────────────
# 이미 만들어둔 base64 문자열(헤더 없이 순수 base64)이라고 가정
# 예: base64_image = encode_image("your.jpg")
assert 'base64_image' in globals(), "base64_image 변수가 먼저 정의되어 있어야 합니다."
img_bytes = base64.b64decode(base64_image)

# ── 2) 모델 호출 ────────────────────────────────────────────────────────
model = genai.GenerativeModel(
    model_name="gemini-2.5-flash",
    generation_config=genai.types.GenerationConfig(
        temperature=0.2, top_p=0.95, max_output_tokens=2048
    )
)

prompt = "이 이미지를 객관적으로 설명해 주세요."
parts = [prompt, {"mime_type": "image/jpeg", "data": img_bytes}]
result = model.generate_content(parts)

# ── 3) 결과 출력(간단) ──────────────────────────────────────────────────
print(getattr(result, "text", "").strip())
# Out:
# 이 이미지는 아프리카 사바나를 배경으로 한 석양 또는 일출 풍경을 담고 있습니다.
#
# *   **하늘:** 상단은 짙은 주황색에서 아래로 갈수록 노란색이 섞인 밝은 주황색으로 그라데이션을 이룹니다. 오른쪽 상단에는 지평선 너머로 솟아오르거나 지고 있는 둥근 해가 밝은 흰색 또는 연노란색으로 빛나고 있습니다.
# *   **배경:** 지평선 멀리에는 희미하게 보이는 여러 겹의 산맥이 어두운 보라색 또는 짙은 붉은색 실루엣으로 펼쳐져 있습니다. 산맥 아래로는 낮은 관목과 나무들이 띠를 이루고 있습니다.
# *   **전경 및 중경:** 건조하고 황금빛 갈색을 띠는 마른 풀밭이 넓게 펼쳐져 있습니다. 풀은 비교적 키가 크고 듬성듬성 나 있습니다.
# *   **주요 피사체:** 이미지 중앙에서 약간 왼쪽에 세 마리의 기린이 서 있습니다.
#     *   가장 왼쪽의 기린은 정면을 향하고 있으며, 가운데 기린은 오른쪽을 바라보고 있고, 가장 오른쪽 기린도 오른쪽을 향하고 있습니다.
#     *   모든 기린은 특징적인 갈색과 크림색의 얼룩무늬를 가지고 있으며, 긴 목과 다리가 뚜렷하게 보입니다.
#     *   기린들의 몸통은 서로 약간 겹쳐져 있습니다.
# *   **전반적인 분위기:** 따뜻하고 부드러운 빛이 이미지 전체에 드리워져 있으며, 주황색과 갈색 계열의 색상이 지배적입니다.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import mimetypes # 파일의 MIME 타입을 추측하기 위해 추가

# --- API 키 설정 ---
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

try:
    # 1. 분석할 로컬 이미지 파일들의 경로를 리스트로 만듭니다.
    image_paths = [
        r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133893700991232898.jpg",  # <-- 첫 번째 이미지 경로
        r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133897221108322618.jpg"  # <-- 두 번째 이미지 경로
    ]

    # 2. 프롬프트와 이미지 데이터를 담을 최종 리스트를 준비합니다.
    #    가장 첫 번째 요소는 텍스트 프롬프트입니다.
    prompt_parts = [
        "각 이미지에 대해 순서대로 설명해주세요. 첫 번째 이미지는 무엇이고, 두 번째 이미지는 무엇인가요?"
    ]

    # 3. 각 이미지 경로를 순회하며 데이터를 읽고 리스트에 추가합니다.
    for path in image_paths:
        if not os.path.exists(path):
            raise FileNotFoundError(f"'{path}' 파일을 찾을 수 없습니다.")

        # 파일 확장자를 기반으로 MIME 타입 추측
        mime_type, _ = mimetypes.guess_type(path)
        if mime_type is None:
            # 추측이 안될 경우 기본값 지정
            mime_type = "application/octet-stream"

        # 파일을 바이너리 읽기 모드('rb')로 열어 prompt_parts 리스트에 추가
        with open(path, 'rb') as f:
            prompt_parts.append({
                'mime_type': mime_type,
                'data': f.read()
            })
    # ------------------------------------

    # 모델 설정
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash",
        generation_config=genai.types.GenerationConfig(
            temperature=0.2,
            top_p=0.95,
            max_output_tokens=2048,
        )
    )

    # 프롬프트와 모든 이미지 데이터가 담긴 리스트를 전달합니다.
    response = model.generate_content(prompt_parts)

    # 결과 출력
    print(response.text)

except FileNotFoundError as e:
    print(f"오류: {e}")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 각 이미지에 대해 순서대로 설명해 드리겠습니다.
#
# **첫 번째 이미지:**
# 이 이미지는 아프리카 사바나를 배경으로 한 세 마리의 기린이 서 있는 모습입니다. 해가 지는(또는 뜨는) 아름다운 순간을 포착한 것으로, 하늘은 강렬한 주황색과 노란색으로 물들어 있습니다. 지평선 위로 붉은 태양이 낮게 떠 있으며, 주변은 마른 풀이 우거진 넓은 초원입니다. 멀리 희미하게 산맥의 실루엣이 보입니다. 평화롭고 웅장한 아프리카의 풍경을 보여줍니다.
#
# **두 번째 이미지:**
# 이 이미지는 넓게 펼쳐진 모래 해변과 사구(모래 언덕)의 풍경입니다. 전경에는 바람에 의해 생긴 듯한 물결 모양의 무늬가 있는 고운 모래가 보이며, 그 뒤로는 풀이 드문드문 자란 완만한 모래 언덕들이 이어집니다. 하늘은 구름이 낀 흐린 날씨를 보여주지만, 전반적으로 밝은 분위기입니다. 햇빛이 모래 표면에 그림자와 질감을 만들어내어 입체감을 더합니다. 고요하고 자연 그대로의 해안 풍경을 담고 있습니다.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import base64
import mimetypes # 파일의 MIME 타입을 추측하기 위해 추가

# --- 이미지 Base64 인코딩 함수 ---
def encode_image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# --- API 키 설정 ---
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

try:
    # 1. 분석할 이미지 파일들의 경로를 리스트로 관리합니다.
    image_paths = [
        r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133893700991232898.jpg", # 첫 번째 이미지
        r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\133897221108322618.jpg"  # 두 번째 이미지
    ]

    # 2. 모델에 전달할 최종 리스트를 준비합니다. (첫 요소는 텍스트 프롬프트)
    prompt_parts = [
        "이 이미지들을 비교해줘."
    ]

    # 3. 각 이미지 경로를 순회하며 데이터를 처리하고 리스트에 추가합니다.
    for path in image_paths:
        if not os.path.exists(path):
            raise FileNotFoundError(f"'{path}' 파일을 찾을 수 없습니다.")
        
        # 이미지를 base64 문자열로 인코딩
        base64_image = encode_image_to_base64(path)
        
        # Base64 문자열을 디코딩하여 이미지 바이트 얻기
        image_bytes = base64.b64decode(base64_image)
        
        # 파일 확장자를 기반으로 MIME 타입 추측
        mime_type, _ = mimetypes.guess_type(path) #mime_type, _ 튜플의 언패킹 --> jpeg 등의 확장자와 인코딩 방식 2개를 저장
        if mime_type is None:
            mime_type = "application/octet-stream" # 타입을 모를 경우의 기본값

        # 이미지 데이터를 딕셔너리 형태로 만들어 리스트에 추가
        prompt_parts.append({
            'mime_type': mime_type,
            'data': image_bytes
        })
    # ------------------------------------

    # 모델 설정
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash", 
        generation_config=genai.types.GenerationConfig(
            temperature=0.2,
            top_p=0.95,
            max_output_tokens=2048,
        )
    )

    # 프롬프트와 모든 이미지 데이터가 담긴 리스트를 전달
    response = model.generate_content(prompt_parts)

    # 결과 출력
    print(response.text)

except FileNotFoundError as e:
    print(f"오류: {e}")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 두 이미지는 모두 자연의 아름다움을 담고 있지만, 매우 다른 풍경과 분위기를 보여줍니다.
#
# **공통점:**
# *   **자연 풍경:** 두 이미지 모두 인공적인 요소가 거의 없는 광활한 자연 풍경을 보여줍니다.
# *   **개방된 공간:** 넓게 펼쳐진 지평선과 탁 트인 공간감을 느낄 수 있습니다.
# *   **자연광:** 인공 조명 없이 자연광에 의해 비춰진 장면입니다.
# *   **흙/모래 톤:** 전반적으로 갈색, 노란색 계열의 흙 또는 모래 색상이 지배적입니다.
#
# **차이점:**
#
# 1.  **주제 (Subject):**
#     *   **첫 번째 이미지:** 세 마리의 기린이 주요 피사체로, 야생 동물의 존재감이 두드러집니다.
#     *   **두 번째 이미지:** 모래 언덕과 해변의 풍경 자체가 주된 피사체이며, 생물은 거의 보이지 않습니다.
#
# 2.  **환경 (Environment):**
#     *   **첫 번째 이미지:** 아프리카 사바나 또는 초원 지대로 보이며, 건조한 풀과 멀리 산맥이 보입니다.
#     *   **두 번째 이미지:** 해안가의 모래 언덕(사구)과 해변으로, 바람에 의해 형성된 모래의 물결 무늬가 특징입니다.
#
# 3.  **시간 및 조명 (Time and Lighting):**
#     *   **첫 번째 이미지:** 해 질 녘(일몰)의 극적인 순간을 포착했습니다. 주황색과 붉은색으로 물든 하늘과 지는 해가 강렬한 인상을 줍니다.
#     *   **두 번째 이미지:** 해가 낮게 떠 있는 늦은 오후 또는 이른 아침으로 보입니다. 부드러운 햇살이 모래 표면을 비추고 있으며, 하늘에는 구름이 많아 빛이 다소 확산되어 있습니다.
#
# 4.  **색감 및 분위기 (Color Palette and Mood):**
#     *   **첫 번째 이미지:** 주황색, 노란색, 갈색 등 **따뜻하고 강렬한 색감**이 지배적이며, 장엄하고 야성적인 분위기를 연출합니다.
# ...

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
import base64
import mimetypes # 파일의 MIME 타입을 추측하기 위해 추가

# --- 이미지 Base64 인코딩 함수 ---
def encode_image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# --- API 키 설정 ---
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

try:
    # 1. 분석할 이미지 파일들의 경로를 리스트로 관리합니다.
    image_paths = [
        r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\pics\oecd_rnd_2021_large.png", # 첫 번째 이미지
        r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\pics\oecd_rnd_2022.png"  # 두 번째 이미지
    ]

    # 2. 모델에 전달할 최종 리스트를 준비합니다. (첫 요소는 텍스트 프롬프트)
    prompt_parts = [
        "첫 번째는 2021년 데이터이고, 두 번째는 2022년 데이터입니다. 이 데이터에 대해 설명해 주세요. 어떤 변화가 있었나요? 한국 중심으로 설명해주세요"
    ]

    # 3. 각 이미지 경로를 순회하며 데이터를 처리하고 리스트에 추가합니다.
    for path in image_paths:
        if not os.path.exists(path):
            raise FileNotFoundError(f"'{path}' 파일을 찾을 수 없습니다.")
        
        # 이미지를 base64 문자열로 인코딩
        base64_image = encode_image_to_base64(path)
        
        # Base64 문자열을 디코딩하여 이미지 바이트 얻기
        image_bytes = base64.b64decode(base64_image)
        
        # 파일 확장자를 기반으로 MIME 타입 추측
        mime_type, _ = mimetypes.guess_type(path) #mime_type, _ 튜플의 언패킹 --> jpeg 등의 확장자와 인코딩 방식 2개를 저장
        if mime_type is None:
            mime_type = "application/octet-stream" # 타입을 모를 경우의 기본값

        # 이미지 데이터를 딕셔너리 형태로 만들어 리스트에 추가
        prompt_parts.append({
            'mime_type': mime_type,
            'data': image_bytes
        })
    # ------------------------------------

    # 모델 설정
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash", 
        generation_config=genai.types.GenerationConfig(
            temperature=0.2,
            top_p=0.95,
            max_output_tokens=4096,
        )
    )

    # 프롬프트와 모든 이미지 데이터가 담긴 리스트를 전달
    response = model.generate_content(prompt_parts)

    # 결과 출력
    print(response.text)

except FileNotFoundError as e:
    print(f"오류: {e}")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 제공해주신 두 그래프는 OECD 주요 회원국 및 비회원국의 연구개발(R&D) 투자 현황을 보여줍니다. 첫 번째 그래프는 2021년 데이터를 주로 포함하고 있으며, 두 번째 그래프는 2022년 데이터를 주로 포함하고 있습니다. 각 그래프는 '연구개발비(백만 US 달러)'를 막대 그래프로, 'GDP 대비 연구개발비 비중(%)'을 노란색 원으로 나타냅니다.
#
# **전반적인 설명 및 변화:**
#
# 1.  **환율 변화:**
#     *   2021년 데이터 기준 환율: 1,143.96원/달러 (OECD 기준)
#     *   2022년 데이터 기준 환율: 1,291.45원/달러 (OECD 기준)
#     *   **변화:** 2021년 대비 2022년에 원/달러 환율이 약 147.49원 상승했습니다. 이는 원화 가치가 하락(달러 강세)했음을 의미합니다. 이로 인해 한국의 원화 기준 연구개발비가 달러로 환산될 때 상대적으로 적게 보일 수 있지만, 제시된 데이터는 이미 달러로 환산된 값입니다.
#
# 2.  **전반적인 연구개발비 증가 추세:**
#     *   대부분의 국가에서 2021년 대비 2022년에 연구개발비(백만 US 달러)가 증가하는 추세를 보입니다. 이는 전 세계적으로 연구개발 투자가 확대되고 있음을 시사합니다.
#     *   미국, 중국, 일본, 독일 등 주요 경제 대국들은 여전히 압도적인 규모의 연구개발비를 지출하고 있습니다.
#
# 3.  **GDP 대비 연구개발비 비중:**
#     *   이스라엘이 두 해 모두 가장 높은 GDP 대비 연구개발비 비중을 유지하고 있으며, 한국이 그 뒤를 이어 2위를 차지하고 있습니다. 이는 이들 국가가 경제 규모에 비해 연구개발에 매우 집중적으로 투자하고 있음을 보여줍니다.
#
# ---
#
# **한국 중심의 설명 및 변화:**
#
# **1. 2021년 데이터 (첫 번째 그래프):**
#
# ...

# %%
#프롬프트를 활용해 문제 만들기

import google.generativeai as genai
import os
from dotenv import load_dotenv
import base64  # base64 라이브러리를 import 합니다.

# 실제 코드에서는 이 base64_image 변수만 준비되면 됩니다.
def encode_image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# 예시 이미지 파일 경로
image_path =r"C:\Users\ziclp\OneDrive\Desktop\LLM Assignment\1week\PRACTICE1\chap6\busan_dive.jpg"
if not os.path.exists(image_path):
    raise FileNotFoundError(f"'{image_path}' 파일을 찾을 수 없습니다.")

# 이미지를 base64 문자열로 인코딩 (이 변수가 준비물입니다)
base64_image = encode_image_to_base64(image_path)
# ----------------------------------------------------------------

# --- API 키 설정 ---
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("API 키를 설정해주세요.")

genai.configure(api_key=api_key)
# ------------------------------------

try:
    # --- 수정된 부분 ---
    # 1. requests 라이브러리를 사용하지 않습니다.
    # 2. Base64 문자열을 직접 디코딩하여 이미지 바이트를 얻습니다.
    image_bytes = base64.b64decode(base64_image)
    
    # 텍스트 프롬프트와 이미지 데이터를 딕셔너리 형태로 준비
    image_data = {
        'mime_type': 'image/jpeg',  # 이미지 형식 지정
        'data': image_bytes         # 디코딩된 바이트 데이터
    }
    # -------------------

    # 모델 설정
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash", #최신 모델 사용 권장
        generation_config=genai.types.GenerationConfig(
            temperature=0.2,
            top_p=0.95,
            max_output_tokens=2048,
        )
    )

    # 프롬프트와 이미지 데이터 전달
    prompt = """
    제공된 이미지를 바탕으로, 다음과 같은 양식으로 퀴즈를 만들어주세요. 
    정답은 1~4 중 하나만 해당하도록 출제하세요.
    토익 리스닝 문제 스타일로 문제를 만들어주세요.
    아래는 예시입니다. 
    ----- 예시 -----

    Q: 다음 이미지에 대한 설명 중 옳지 않은 것은 무엇인가요?
    - (1) 베이커리에서 사람들이 빵을 사고 있는 모습이 담겨 있습니다.
    - (2) 맨 앞에 서 있는 사람은 빨간색 셔츠를 입고 있습니다.
    - (3) 기차를 타기 위해 줄을 서 있는 사람들이 있습니다.
    - (4) 점원은 노란색 티셔츠를 입고 있습니다.

    Listening: Which of the following descriptions of the image is incorrect?
    - (1) It shows people buying bread at a bakery.
    - (2) The person standing at the front is wearing a red shirt.
    - (3) There are people lining up to take a train.
    - (4) The clerk is wearing a yellow T-shirt.
        
    정답: (4) 점원은 노란색 티셔츠가 아닌 파란색 티셔츠를 입고 있습니다.
    (주의: 정답은 1~4 중 하나만 선택되도록 출제하세요.)
    ======
    """
    response = model.generate_content([prompt, image_data])

    # 결과 출력
    print(response.text)

except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# Q: 다음 이미지에 대한 설명 중 옳지 않은 것은 무엇인가요?
# - (1) 행사는 "DIVE 2024 IN BUSAN"이라는 이름으로 진행되고 있습니다.
# - (2) 많은 참가자들이 테이블에 앉아 노트북을 사용하고 있습니다.
# - (3) 행사장에는 비상구 표지판이 보입니다.
# - (4) 참가자들은 주로 서서 강연을 듣고 있습니다.
#
# Listening: Which of the following descriptions of the image is incorrect?
# - (1) The event is being held under the name "DIVE 2024 IN BUSAN."
# - (2) Many participants are seated at tables, using laptops.
# - (3) An emergency exit sign is visible in the event hall.
# - (4) Participants are mostly standing and listening to a lecture.
#
# 정답: (4) 참가자들은 주로 테이블에 앉아 노트북을 사용하고 있으며, 서서 강연을 듣는 모습은 보이지 않습니다.
