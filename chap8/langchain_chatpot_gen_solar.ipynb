# %%
# %pip install langchain_google_genai
# %pip install langchain-openai
# %pip install python-dotenv
# %pip install --upgrade jupyter ipywidgets
# %pip install --upgrade transformers datasets[audio] accelerate
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage  # 원본 스니펫 import

# 1. .env 파일에서 환경 변수 로드
load_dotenv()

# 2. 모델 초기화 (Gemini)
# (os.environ['GOOGLE_API_KEY'] = ... 설정은 라이브러리가 자동으로 처리)
model = ChatGoogleGenerativeAI(model="gemini-2.5-pro")

# --- [원본 코드 스니펫 시작] ---
# (from langchain_core.messages import HumanMessage 는 상단으로 이동)
response = model.invoke([HumanMessage(content="안녕? 나는 누노 베텐코트야.")])
# --- [원본 코드 스니펫 끝] ---

print(response.content)
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 2
# Please retry in 11.692269432s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 2
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ].
# ...

# %%
response2 = model.invoke([HumanMessage(content="내 이름이 뭐지?")])
print(f"AI 응답 2: {response2.content}")
# Out:
# AI 응답 2: 저는 사용자의 개인 정보에 접근할 수 없기 때문에, 이름을 알지 못합니다. 저는 사용자의 개인정보 보호를 위해 설계된 AI입니다.
#
# 혹시 이름을 알려주시면, 대화하는 동안 기억하고 그렇게 불러드릴 수 있습니다.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage  # 원본 스니펫 import

# 1. .env 파일에서 환경 변수 로드
load_dotenv()

# 2. 모델 초기화 (Upstage)
model = ChatOpenAI(
    model="solar-pro2",
    api_key=os.getenv("UPSTAGE_API_KEY"),
    base_url="https://api.upstage.ai/v1"
)

# --- [원본 코드 스니펫 시작] ---
# (from langchain_core.messages import HumanMessage 는 상단으로 이동)
response = model.invoke([HumanMessage(content="안녕? 나는 찰스 올리베이라야.")])
# --- [원본 코드 스니펫 끝] ---

print(response.content)
# Out:
# 안녕하세요! 찰스 올리베이라님, 만나서 반갑습니다. 😊
# (브라질 출신의 UFC 파이터이자 현 라이트급 챔피언으로 알고 있는데, 맞으시죠?)
#
# 오늘 기분이 어떠신가요? 훈련이나 경기 관련 이야기가 궁금하네요.
# 또는 UFC나 MMA에 대해 궁금한 점이 있다면 무엇이든 물어보세요!
#
# > *참고로, 저는 AI 어시스턴트이기 때문에 실제 인물과는 실시간으로 소통할 수 없습니다. 찰스님의 팬으로서 응원한다는 메시지를 전합니다! 🥊*
#
# 궁금한 주제가 있다면 계속 대화를 나눠요!

# %%
response2 = model.invoke([HumanMessage(content="내 이름이 뭐지?")])
print(f"AI 응답 2: {response2.content}")
# Out:
# AI 응답 2: 저는 사용자의 개인 정보를 알 수 없도록 설계되었기 때문에, 아쉽게도 당신의 이름을 알지 못합니다.
#
# 혹시 이름을 알려주시면, 이번 대화가 진행되는 동안에는 기억하고 불러드릴게요.
